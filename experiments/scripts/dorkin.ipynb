# %%
trained_grades = list(range(2, 13))  # grades 2 to 12
grades = [str(f'{grade:02}') for grade in trained_grades]
string = "grade: {}"
for grade in grades:
    print(string.format(grade))
# Out:
# grade: 02
# grade: 03
# grade: 04
# grade: 05
# grade: 06
# grade: 07
# grade: 08
# grade: 09
# grade: 10
# grade: 11
# grade: 12
